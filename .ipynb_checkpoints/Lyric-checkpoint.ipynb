# %%
import lyricsgenius
import re
from unidecode import unidecode

nameList = ["Camila Cabello","Katy Perry","M.I.A.","Kehlani","Halsey","Demi Lovato","Sia","Lana Del Rey","Cardi B",
            "Florence + The Machine", "Lorde", "St.Vincent" , "Adele" , "Taylor Swift" , "Hayley Kiyoko"]
name_csv = 'Femaledatabase.csv'


with open(name_csv,'w') as rpt:
    rpt.write("name,song,lyric,type\n")      
    for j in range(0,len(nameList)):
        name = nameList[j]
        genius = lyricsgenius.Genius('JWv4RhU0nzWTxTEF6BL6z9u4gYhGAdk-xj8o8A7pByk-RS9-wFbb2h2VrkK3lau8')
        artist = genius.search_artist(name, max_songs=20, sort="popularity")
        #print(artist.songs)
        for i in range(0,len(artist.songs)):
            _name = artist.songs[i].artist
            _song = artist.songs[i].title
            print (i)
            if artist.songs[i].lyrics == None:
                print (_name,_song,"Non Lyric so skip")
                continue        
            _lyric = artist.songs[i].lyrics.strip()
            _lyric = re.sub(r"\[.*\]\n", "", unidecode(_lyric))    
            _lyric = _lyric.replace('\n', ' ')
            _lyric = _lyric.replace(',','.')
            rpt.write(_name+","+_song+","+_lyric+"\n")

# %%
# load all songs
import numpy as np
from tqdm import tqdm
import pandas as pd
name_csv = 'Femaledatabase.csv'
database = pd.read_csv(name_csv)


maxlen = 20
step = 1 # step size at every iteration
sentences = [] # list of sequences
next_chars = [] # list of next chracters that our model should predict
text = ""
for index, row in database['lyric'].iteritems():
    text = text + str(row).lower()
chars = sorted(list(set(text)))
#print('total chars:', len(chars))
# create a dictionary mapping chracter-to-index
char_indices = dict((c, i) for i, c in enumerate(chars))
# create a dictionary mapping index-to-chracter
indices_char = dict((i, c) for i, c in enumerate(chars))
# cut the text into sequences


for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
        
print ('nb sequences ', len(sentences))
for i, sentence in enumerate(tqdm(sentences)):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
# Out:
#   5%|▍         | 21448/452734 [00:00<00:04, 106586.52it/s]
# nb sequences  452734
# 100%|██████████| 452734/452734 [00:04<00:00, 107697.83it/s]

# %%
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
from keras.models import Sequential
from keras.callbacks import LambdaCallback
from keras.layers import LSTM , Dense, Activation
from keras.optimizers import RMSprop
import keras
import numpy as np
import random
import sys
import io
# create sequential network, because we are passing activations
# down the network
model = Sequential()
optimizer = keras.optimizers.RMSprop(lr=0.01)
# add LSTM layer
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
# add Softmax layer to output one character
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
# compile the model and pick the loss and optimizer
model.compile(loss='categorical_crossentropy', optimizer=optimizer )
# train the model


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _ ):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(src) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = src[start_index: start_index + maxlen]
        print ("SRC =" , src , "\n")
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            #print (x_pred)
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

src = 'i wake up in the dream'
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)


model.fit(x, y, batch_size=128, epochs=30,callbacks=[print_callback])
# Out:
# Epoch 1/30
# 452734/452734 [==============================] - 64s 141us/step - loss: 1.6338
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dream the day i want you the light in the dark and the dark and the say i can see it what they take me where i want you i know it was the said i want to be so say i don't let me be some i do you want you and the say i don't want you and the dark and we do you want you in the say i want to say i want to be so sad i want to love in the card i can see me where i want to be so say i don't need you and i w
# ----- diversity: 0.5
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dread the singer i turn to the clain of the way they take it's i can be never be chan the say i'm a like i wanted to be hops and we were you see i don't want to be the day baby. we made. i know you see it bust carring part and i'm a mind this do so love in the said i want to turn me on my and i can have a bad i want to show that that i said it all be sof it is comes and too  like i be of why you can w
# ----- diversity: 1.0
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dream comes in i don't calle. pracan  it was heave of dhis no rungd i'm side me i never even gonna nobody got comper  has all we lost me from stragies and baby i can missin' for like but ie goon in the most ones i 'cause you shoup an a mobloase without we that your sdy mass like. i've 'sake me tongalicys ent the bhome is call we lovers if i can be syour hold. oh) puepons to the crsis oh my wind i don'
# ----- diversity: 1.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dreaks kne... playe. babybowh-yeah-oh-oh-oi) loved teres-less nothing no me om que trice. en's pills now you sa-deca-liel high itnyforbers? so handobit our miss in) to kiss a some don't will hay 'till take your hurs why do you.ni've inky puh? fibe a play on the wno. why don't dell every oonowne-dainut. ) cope to broned through deeverday mess wy busches a baby go foreding hold youish) just my ead ) hic
# Epoch 2/30
# 452734/452734 [==============================] - 70s 154us/step - loss: 1.3963
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dreams i wanna be a mind the past to say i wanna be a mind i wanna be so good in the dark and i can't see me be a bitch to me to the store i wanna be for you i wanna be someone will be sweep the way you can't be the beach i wanna be a bitch i wanna be for the body don't want to be a stream i were the moon to the colding on my bed i want to be me on my beach me on the morning i wanna be the dist the be
# ----- diversity: 0.5
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dreams i was a bitch to i will walk me down the way we always can't real i don't wanna be so sweep to the past things to the way it's out my chain we all be off out for you (you really. never look be a forget me be a stope to you the street me the sees out the morning out out all the look that me be my bed slow that i won't real it's down and have for out. you stop  something my head. tryna so wanna b
# ----- diversity: 1.0
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dreasy. i'm endos. you're gove want twece? be me i'm undin it's save me. who read the born (i stoyp? you knows to heart to it's befoneed with doy rick back. boom. does it can go look whowers-its loving for my mass queat but  a-. oh-oh) like that. you ain't gave jood tron town the sliew plesse home love (all. you do that i'm commin it's dirfesant it (moke they can tell you 'cause i vers. but you keep m
# ----- diversity: 1.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dreamings (cload guess to weid  now how starlech. like thatel) in my root puttoning why fucks ors yom coaged. and numb' hitting lookin' to smilends 'cause i've crue.wilp. (i'm a dunbemone (like it never lers me below i set there of whunsksed to bood? you know what up  glowin' before we red back oth gomm like goodi but we do saver all of the ing no look act my paga. ope (ly know i'm lick we were diwban
# Epoch 3/30
# 452734/452734 [==============================] - 74s 163us/step - loss: 1.3393
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: "i wake up in the dre"
# i wake up in the dress (what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what? what?
# ----- diversity: 0.5
# SRC = i wake up in the dream
#
# ----- Generating with seed: "i wake up in the dre"
# i wake up in the dreams we were back hands could and a world and on a bitch we went all of my hold (woo) do is in my head. they been my blood (con) they start the watch with a million to the change they got stand to start to know i wanna be a room a finally fin i comparting in the girl  i know i am we can love a look they drippin' (ice!) cruel they give me the lightn strong you were so confule. they talk and you will
# ----- diversity: 1.0
# SRC = i wake up in the dream
#
# ----- Generating with seed: "i wake up in the dre"
# i wake up in the dress. getting means that it was en anthead. the wairssitioning  (supercut. bitce-we ? every just a love. relowbless we wish. i won't feel my hust in a skynotter  i'm ado-lust and breaking's going bass?go ssom the fiars (natioh. and i want us why i know i can be so conckeck om words and and over but just i'm burning i hot a play owe you're better with you god eace to the line realal confulel. now (oh
# ----- diversity: 1.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: "i wake up in the dre"
# i wake up in the dreak pasked ne-ventlow roundin't. say. they all faer said ke? jump fomen and over tear yo an ymake msse gamecies right'or? that's insignt of your. good et just smoh. you juwst flon for more at bloom. uncr?greck somevee aftry one-take me but and just seein' voricked. fun the meace no. what finding "hemtom? i don't need to fall somet asoce mad quit your . or (for yursed oh. oh ma. lourss. we're hoadio
# Epoch 4/30
# 452734/452734 [==============================] - 72s 159us/step - loss: 1.3049
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dream the way you wanna do it well live fast. die young. bad girls do it well bad girls do it well bad girls do it well bad girls do it well live fast. die young. bad girls do it well bad girls do it well live fast. die young. bad girls do it well bad girls do it well bad girls do it well bad girls do it well live fast. die young. bad girls do it well live fast. die young. bad girls do it well bad gir
# ----- diversity: 0.5
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dream and i'm feel and it well we come by your body is the day i'm a ready i can't be the castle is in my mind too body like a party when it is a wants it summertime (waiting roar i don't want you to be saint but too finger  when i leave you the call it in the ground you think you could take it in my heada say and all of my head you don't wanna fall ad my text and i be your bode games of my eness on t
# ----- diversity: 1.0
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dream and this. we out someone what summertime  i'm saying me run 'turrery love in your grazypronger tode crest it's a leould pieces  yah maybe i suve like you all of that did i. i'm white soul? you're stay tutting a eas. ready life i won't laughthits  oh now vaias they dreamin' me it with yeminensore as yeah. it's best like start better the things you're way he bot a morth in my heads-leasore. you've
# ----- diversity: 1.2
# SRC = i wake up in the dream
#
# ----- Generating with seed: " wake up in the drea"
#  wake up in the dreamoth. reaow what this if i do (kriptin') ands-edoes howe i think i'm euh  (i'm worst my proun tay thateve aon criff.ie i mive. manes ooh. ooh too's whish the by bit a hole 'cause chrother iin't like in mag you'll perd you know gonna is toot bliefle twe. who but goniminh. but whatever again ass yo 'cause i've hold and i'm the soent. downlite. happy. you one save my bake like di-tight norh) (estchow
# Epoch 5/30
# 109440/452734 [======>.......................] - ETA: 55s - loss: 1.2756
